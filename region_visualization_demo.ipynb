# %% [markdown]
# # Visual Genome Region Description Visualization
#
# In this demo, we will demonstrate how you can get use the [Visual Genome Python Driver](https://github.com/ranjaykrishna/visual_genome_python_driver) to get images and also their regions. Next, we will show you how you can visualize the regions to make sure that they work.

# %%
# !git clone https://github.com/ranjaykrishna/visual_genome_python_driver.git VG-API
# %cd /content/VG-API/
# !pip install .
# Out:
# Cloning into 'VG-API'...
# remote: Enumerating objects: 407, done.
# remote: Total 407 (delta 0), reused 0 (delta 0), pack-reused 407
# Receiving objects: 100% (407/407), 926.84 KiB | 21.06 MiB/s, done.
# Resolving deltas: 100% (232/232), done.
# /content/VG-API
# Processing /content/VG-API
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from visual-genome==1.0.0) (2.23.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->visual-genome==1.0.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->visual-genome==1.0.0) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->visual-genome==1.0.0) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->visual-genome==1.0.0) (1.24.3)
# Building wheels for collected packages: visual-genome
#   Building wheel for visual-genome (setup.py) ... done
#   Created wheel for visual-genome: filename=visual_genome-1.0.0-cp36-none-any.whl size=10301 sha256=3f08ebd2397458017d80e4d5a05b52b01f5955a924748b850488bd5626abaa67
#   Stored in directory: /root/.cache/pip/wheels/f5/2b/83/0a68736b5166bd48d68feeee66b2fc0e12c596cef745e93846
# Successfully built visual-genome
# Installing collected packages: visual-genome
# Successfully installed visual-genome-1.0.0

# %% [markdown]
# ### Getting an image id
# First, let's get an image from the dataset.

# %%
from visual_genome import api
ids = api.get_all_image_ids()
print(ids[0])
# Out:
# 1

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from visual_genome import api as vg
from PIL import Image
import requests
from io import StringIO, BytesIO

# %%
ids = vg.get_image_ids_in_range(start_index=0, end_index=1)
image_id = ids[0]
print("We got an image with id: %d" % image_id)

# %matplotlib inline
# Out:
# We got an image with id: 1

# %% [markdown]
# ### Getting the image data
# Next, we will get some data about the image. We specifically want to know the image's url.

# %%
image = vg.get_image_data(id=image_id)
print("The url of the image is: %s" % image.url)
# Out:
# The url of the image is: https://cs.stanford.edu/people/rak248/VG_100K_2/1.jpg

# %% [markdown]
# ### Getting the region descriptions
# Now, let's get all the region descriptions for this image.

# %%
regions = vg.get_region_descriptions_of_image(id=image_id)
print("The first region descriptions is: %s" % regions[0].phrase)
print("It is located in a bounding box specified by x:%d, y:%d, width:%d, height:%d" % (regions[0].x, regions[0].y, regions[0].width, regions[0].height))
# Out:
# The first region descriptions is: the clock is green in colour
# It is located in a bounding box specified by x:421, y:57, width:82, height:139

# %% [markdown]
# ### Visualizing some regions
# Now, we will visualize some of the regions. The x,y coordinates of a region refer to the top left corner of the region. Since there are many regions, we will only visualize the first 4.

# %%
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)
def visualize_regions(image, regions):
    response = requests.get(image.url)
    img = Image.open(BytesIO(response.content))
    plt.imshow(img)
    ax = plt.gca()
    for region in regions:
        ax.add_patch(Rectangle((region.x, region.y),
                               region.width,
                               region.height,
                               fill=False,
                               edgecolor='red',
                               linewidth=3))
        ax.text(region.x, region.y, region.phrase, style='italic', bbox={'facecolor':'white', 'alpha':0.7, 'pad':10})
    fig = plt.gcf()
    plt.tick_params(labelbottom='off', labelleft='off')
    plt.show()
visualize_regions(image, regions[:8])
